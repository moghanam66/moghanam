# %%
class zone :
    z = int(input ("enter the zone range"))
    
class player :
    
    def __init__(self ):
        self.x =0
        self.y =0
        self.v =0
      
    def forward(self):
        self.y += self.v
        self.v +=10
        print(self.x , self.y , self.v)
        
    def back (self):
        if self.v <0:
            self.v =0
        self.y +=self.v
        self.v -=10
        
        print(self.x , self.y , self.v)
        
    def right (self):
       
        self.x += self.v
        self.v -=20
        if self.v <= 0:w
            self.v=0
        print(self.x , self.y , self.v)
        
    def left (self):
        
        
        self.x -= self.v
        self.v -=20
        if self.v <= 0:
            self.v=0
        print(self.x , self.y , self.v)

###############################################################################################
class enemy :
    
    
    def __init__(self ):
        self.x =zone.z
        self.y =zone.z
        self.v =0
        
    def forward(self):
        self.y -= self.v
        self.v +=10
        if self.v <0:
            self.v =0
            
        if self.y >= zone.z:
            self.y =zone.z
        elif self.y<=0:
            self.y =0
        print(self.x , self.y , self.v)
        
    def back (self):
        self.y +=self.v
        self.v -=10
        
            
        if self.y >= zone.z:
            self.y =zone.z
        elif self.y<=0:
            self.y =0
        print(self.x , self.y , self.v)
        
    def right (self):
       
        self.x -= self.v
        self.v -=20
        if self.v <= 0:
            self.v=0
        print(self.x , self.y , self.v)
        
    def left (self):
        
        self.x += self.v
        self.v -=20
        if self.v <= 0:
            self.v=0
        print(self.x , self.y , self.v)
          
##################################################################################       
        
class display :
    n=0
    def __init__(self):
        print ("welcome to my Game")
        print("this game is about trying to reach the end of the selected zone with 0 speed \n the player should ty to reach the end of zone with speed 0 \n the enemy should try to catch the player so if the enemy succeeded in intersecting the coordinates of the player,the game ends\n ")
        print("the zone is a square zone you will be orderd to select the range of your zone")
        print("player and enemy shuld enter :\n 'w' for moving forward \n 's'for moving backward \n 'a' for turning left \n 'd' for turning right")
        print()
        print("the initial position of the player is (0,0) \nthe initial position of enemy is ({},{})".format(zone.z , zone.z))
    def player_full_success (self):
        print ("congratulations player succeeded in passing te enemy ,reaching the destination with speed 0 ")
        
    def player_fail(self):
        print ("congratulations player succeeded in passing te enemy but with high speed not zero")

    def  enemy_success(self):
        print ("enemy succeeded in catching the player ")


###################################################################################        
d=display()
zone=zone()        
car1 = player()
enemy = enemy()
while  (car1.y <zone.z  or car1.x==enemy.x or car1.y==enemy.y) :
    
    x= input( )
    if x :
        d.n+=1
        
    if d.n %2 ==0 :
    
        if x == 'w':
            print ("player position:")
            car1.forward()
        elif x == 's':
            print ("player position :")
            car1.back()
        elif x == 'd':
            print ("player position :")
            car1.right()
        elif x == 'a':
            print ("player position :")
            car1.left()
        else :
            print("wrong  player aswer")
            
    elif d.n %2 !=0 :
        if x == 'w':
            print ("enemy position :")
            enemy.forward()
        elif x == 's':
            print ("enemy position :")
            enemy.back()
        elif x == 'd':
            print ("enemy position:")
            enemy.right()
        elif x == 'a':
            print ("enemy position:")
            enemy.left() 
        else :
            print("wrong enemy answer")
            
if car1.y >=zone.z:
    if car1.v == 0:
        d.player_full_success()
    else:
        d.player_fail()
elif car1.x==enemy.x or car1.y==enemy.y :
    d.enemy_success()
# Out:
# enter the zone range100
# welcome to my Game
# this game is about trying to reach the end of the selected zone with 0 speed
#  the player should ty to reach the end of zone with speed 0
#  the enemy should try to catch the player so if the enemy succeeded in intersecting the coordinates of the player,the game ends
#
# the zone is a square zone you will be orderd to select the range of your zone
# player and enemy shuld enter :
#  'w' for moving forward
#  's'for moving backward
#  'a' for turning left
#  'd' for turning right
#
# the initial position of the player is (0,0)
# the initial position of enemy is (100,100)
# w
# enemy position :
# 100 100 10
# w
# player position:
# 0 0 10
# w
# enemy position :
# 100 90 20
# w
# player position:
# 0 10 20
# w
# enemy position :
# 100 70 30
# w
# player position:
# 0 30 30
# w
# enemy position :
# 100 40 40
# d
# player position :
# 30 30 10
# a
# enemy position:
# 140 40 20
# a
# player position :
# 20 30 0
# d
# enemy position:
# ...
