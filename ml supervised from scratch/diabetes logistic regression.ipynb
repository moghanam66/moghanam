# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("diabetes.csv")

# %%
df.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
print(df.columns)
# Out:
# Index(['Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness', 'Insulin',
#        'BMI', 'DiabetesPedigreeFunction', 'Age', 'Outcome'],
#       dtype='object')

# %%
columns = ['Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness', 'Insulin',
       'BMI', 'DiabetesPedigreeFunction', 'Age', 'Outcome']
df.boxplot(column=columns , figsize=(20,60))
# Out:
# <AxesSubplot:>

# %%
plt.scatter(df['Pregnancies'] , df['Outcome'])

# %%
plt.scatter(df['Glucose'] , df['Outcome'])

# %%
plt.scatter(df['BloodPressure'] , df['Outcome'])

# %%
plt.scatter(df['SkinThickness'] , df['Outcome'])

# %%
plt.scatter(df['Insulin'] , df['Outcome'])

# %%
plt.scatter(df['BMI'] , df['Outcome'])

# %%
plt.scatter(df['DiabetesPedigreeFunction'] , df['Outcome'])

# %%
plt.scatter(df['Age'] , df['Outcome'])

# %%
import seaborn as sns
import matplotlib.pyplot as plt

cor = df.corr()
plt.figure(figsize=(20,15))
sns.heatmap(cor, annot=True, cmap=plt.cm.Reds)
plt.show()

# %%
df['SkinThickness'].value_counts()
# Out:
# 0     227
# 32     31
# 30     27
# 27     23
# 23     22
# 33     20
# 18     20
# 28     20
# 31     19
# 39     18
# 19     18
# 29     17
# 37     16
# 26     16
# 22     16
# 40     16
# 25     16
# 35     15
# 41     15
# 36     14
# 15     14
# 17     14
# 20     13
# 24     12
# 42     11
# 13     11
# 21     10
# 34      8
# 46      8
# 38      7
# 12      7
# 14      6
# 16      6
# 11      6
# 43      6
# 45      6
# 10      5
# 44      5
# 48      4
# 47      4
# 50      3
# 49      3
# 54      2
# 52      2
# 7       2
# 8       2
# 60      1
# 56      1
# 63      1
# 51      1
# 99      1
# Name: SkinThickness, dtype: int64

# %%
df.shape
# Out:
# (768, 9)

# %%
print(df['SkinThickness'].mean())
# Out:
# 20.536458333333332

# %%
df['SkinThickness'] = df['SkinThickness'].replace(0,df['SkinThickness'].mean())

# %%
df.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72      35.000000        0  33.6
# 1            1       85             66      29.000000        0  26.6
# 2            8      183             64      20.536458        0  23.3
# 3            1       89             66      23.000000       94  28.1
# 4            0      137             40      35.000000      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
df['Insulin'].value_counts()
# Out:
# 0      374
# 105     11
# 140      9
# 130      9
# 120      8
#       ...
# 271      1
# 270      1
# 108      1
# 112      1
# 846      1
# Name: Insulin, Length: 186, dtype: int64

# %%
df['BloodPressure'].value_counts()
# Out:
# 70     57
# 74     52
# 68     45
# 78     45
# 72     44
# 64     43
# 80     40
# 76     39
# 60     37
# 0      35
# 62     34
# 66     30
# 82     30
# 88     25
# 84     23
# 90     22
# 86     21
# 58     21
# 50     13
# 56     12
# 52     11
# 54     11
# 92      8
# 75      8
# 65      7
# 94      6
# 85      6
# 48      5
# 44      4
# 96      4
# 110     3
# 100     3
# 98      3
# 106     3
# 108     2
# 104     2
# 30      2
# 55      2
# 46      2
# 40      1
# 38      1
# 24      1
# 95      1
# 61      1
# 102     1
# 114     1
# 122     1
# Name: BloodPressure, dtype: int64

# %%
X = df[['Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness', 'Insulin',
       'BMI', 'DiabetesPedigreeFunction', 'Age']]
y = df['Outcome']

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=0)

# %%
from sklearn.linear_model import LogisticRegression
logisticRegr = LogisticRegression(solver='liblinear')
logisticRegr.fit(X_train, y_train)
# Out:
# LogisticRegression(solver='liblinear')

# %%
score = logisticRegr.score(X_test,y_test)
print(score)
# Out:
# 0.7878787878787878

# %%
x1 = df['Pregnancies']
x1.to_numpy()

x2=df['Glucose']
x2.to_numpy()

x3=df['BloodPressure']
x3.to_numpy()

x4=df['SkinThickness']
x4.to_numpy()

x5=df['Insulin']
x5.to_numpy()

x6=df['BMI']
x6.to_numpy()

x7=df['DiabetesPedigreeFunction']
x7.to_numpy()

x8=df['Age']
x8.to_numpy()

print(len(x8))
# Out:
# 768

# %%
y=df['Outcome']

# %%
h0 = 0
h1 = 0
h2 = 0
h3 = 0
h4 = 0
h5 = 0
h6 = 0
h7 = 0
h8 = 0

lr = 0.00001
h0_lis=[]
h1_lis=[]
h2_lis=[]
h3_lis=[]

loss_funcc=[]
Epochs = []

for i in range (2000):
    
    Epochs.append(i)
    hx = 1 / (1 + np.exp((-1)*(h0 + h1*x1 + h2*x2 + h3*x3 + h4*x4 + h5*x5 + h6*x6 + h7*x7 + h8*x8) ))
    
    #cost_func = (1/(2*len(x1)))*sum((hx-y)**2)
    
    cost_func = (-1 / len(x1)) *(sum((y*np.log(hx))+((1-y)*(np.log(hx)))))
    
    loss_funcc.append(cost_func)
    
    
    g0 =  (1 / len(x1)) * np.sum(hx - y)
    g1 =  (1 / len(x1)) * np.sum((hx - y) * x1)
    g2 =  (1 / len(x2)) * np.sum((hx - y) * x2)
    g3 =  (1 / len(x3)) * np.sum((hx - y) * x3)
    g4 =  (1 / len(x4)) * np.sum((hx - y) * x4)
    g5 =  (1 / len(x5)) * np.sum((hx - y) * x5)
    g6 = (1 / len(x6)) * np.sum((hx - y) * x6)
    g7 = (1 / len(x7)) * np.sum((hx - y) * x7)
    g8 = (1 / len(x8)) * np.sum((hx - y) * x8)
                                 
                                 
                                 
                                 
                                 
                                 
                                 
    
    
    h0 = h0-(lr*g0)
    h1 = h1 - (lr*g1)
    h2 = h2 - (lr*g2)
    h3 = h3 - (lr*g3)
    h4 = h4 - (lr*g4)
    h5 = h5 - (lr*g5)
    h6 = h6 - (lr*g6)
    h7 = h7 - (lr*g7)
    h8 = h8 - (lr*g8)
    
    h0_lis.append(h0)
    h1_lis.append(h1)
    h2_lis.append(h2)
    h3_lis.append(h3)

# %%
print(h0)
# Out:
# -0.0008685099065513217

# %%
print(h5)
# Out:
# 0.0008380799069072559

# %%
pre_y = hx = 1 / (1 + np.exp((-1)*(h0 + h1*x1 + h2*x2 + h3*x3 + h4*x4 + h5*x5 + h6*x6 + h7*x7 + h8*x8) ))

# %%
pre_y.shape
# Out:
# (768,)

# %%
pre_y = pre_y.values.reshape(1,768)

# %%
y.shape
# Out:
# (768,)

# %%
y = y.values.reshape(1,768)

# %%
predicted_classes = (pre_y >= 0.5).astype(int)


predicted_classes = predicted_classes.flatten()

accuracy = np.mean(predicted_classes == y.flatten())
print(accuracy)
# Out:
# 0.6731770833333334
